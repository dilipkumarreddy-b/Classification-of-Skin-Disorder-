# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import warnings
warnings.filterwarnings("ignore")
#pd.pandas.set_option("display.max_rows")

# %% [markdown]
# # Importing data

# %%
df = pd.read_csv("skin disorder.csv")
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
##Setting the maximum columns and to display few rows of data
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  family_history  \
# 0                           1                  0               0
# ...

# %%
df.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %%
df.Age.unique()
# Out:
# array(['55', '8', '26', '40', '45', '41', '18', '57', '22', '30', '20',
#        '21', '10', '65', '38', '23', '17', '51', '42', '44', '33', '43',
#        '50', '34', '?', '15', '46', '62', '35', '48', '12', '52', '60',
#        '32', '19', '29', '25', '36', '13', '27', '31', '28', '64', '39',
#        '47', '16', '0', '7', '70', '37', '61', '67', '56', '53', '24',
#        '58', '49', '63', '68', '9', '75'], dtype=object)

# %%
##Using the replace funtion
df.Age = df.Age.replace(['?'], '36')

# %%
##Since '0'is dropped checking the shape of the dataframe again
df.shape
# Out:
# (366, 35)

# %%
df["Age"]=df["Age"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %%
df.Age.mean()
# Out:
# 36.2896174863388

# %%
df.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
df.rename(columns={"saw-tooth_appearance_of_retes":"saw_tooth_appearance_of_retes",'band-like_infiltrate':'band_like_infiltrate', 'class':'outcome'}, inplace = True)

#using rename to change column name..

# %%
df.columns.to_list()
# Out:
# ['erythema',
#  'scaling',
#  'definite_borders',
#  'itching',
#  'koebner_phenomenon',
#  'polygonal_papules',
#  'follicular_papules',
#  'oral_mucosal_involvement',
#  'knee_and_elbow_involvement',
#  'scalp_involvement',
#  'family_history',
#  'melanin_incontinence',
#  'eosinophils_in_the_infiltrate',
#  'PNL_infiltrate',
#  'fibrosis_of_the_papillary_dermis',
#  'exocytosis',
#  'acanthosis',
#  'hyperkeratosis',
#  'parakeratosis',
#  'clubbing_of_the_rete_ridges',
#  'elongation_of_the_rete_ridges',
#  'thinning_of_the_suprapapillary_epidermis',
#  'spongiform_pustule',
#  'munro_microabcess',
#  'focal_hypergranulosis',
#  'disappearance_of_the_granular_layer',
#  'vacuolisation_and_damage_of_basal_layer',
#  'spongiosis',
#  'saw_tooth_appearance_of_retes',
#  'follicular_horn_plug',
#  'perifollicular_parakeratosis',
#  'inflammatory_monoluclear_inflitrate',
#  'band_like_infiltrate',
#  'Age',
#  'outcome']

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
plt.figure(figsize=(15,15))
sns.histplot(df.Age.dropna(),kde=True)
#NORMALITY CHECK
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(20,20))
plt.rc('xtick',labelsize= 10,color="red") 
plt.rc('ytick', labelsize= 10,color="blue")

plotno=1
for columns in df:
    if plotno<=30:
        plt.subplot(6,5,plotno)
        sns.histplot(df[columns],kde=True)
        plt.xlabel(columns)
    plotno +=1 
plt.show()

# %%
from scipy.stats import skew
for columns in df:
    print(skew(df[columns])," ",columns)
# Out:
# -0.3004337550563441   erythema
# -0.07486788126113575   scaling
# -0.2895896427427566   definite_borders
# 0.09780213871357966   itching
# 1.1818269806585575   koebner_phenomenon
# 1.7992346066638072   polygonal_papules
# 3.5427724305571116   follicular_papules
# 1.9527034462783837   oral_mucosal_involvement
# 1.2291398669224014   knee_and_elbow_involvement
# 1.4499547397718227   scalp_involvement
# 2.2583781213805714   family_history
# 1.8709544091325214   melanin_incontinence
# 3.0699137080508083   eosinophils_in_the_infiltrate
# 1.2162696571610578   PNL_infiltrate
# 2.347223103955705   fibrosis_of_the_papillary_dermis
# -0.008170385897409094   exocytosis
# -0.39187243990471626   acanthosis
# 1.2158796233464129   hyperkeratosis
# 0.03590455382838033   parakeratosis
# 1.17584281565697   clubbing_of_the_rete_ridges
# 0.5402979773141607   elongation_of_the_rete_ridges
# 1.2359043798088272   thinning_of_the_suprapapillary_epidermis
# 2.304563210292065   spongiform_pustule
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  family_history  \
# 0                           1                  0               0
# ...

# %%
sns.histplot(data=df[['Age']],x= 'Age')
plt.title('Age')
plt.show()
##Skin diseases are found majority in the age group between 30-40

# %%
sns.histplot(data=df[['family_history']],x= 'family_history')
plt.title('family_history')
plt.show()
##This shows majority of the disease has not been observed in family

# %% [markdown]
# ### Bivariant Analysis

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  family_history  \
# 0                           1                  0               0
# ...

# %%
df.outcome.unique()
# Out:
# array([2, 1, 3, 5, 4, 6], dtype=int64)

# %%
colors = np.array(['red','blue', 'green','yellow','purple','violet'])

# %%
plt.scatter(x= df.Age, y = df.scaling,c =colors[df.outcome-1])

# %%
def countplot_of_2(x,hue,title=None,figsize=(6,5)):
    plt.figure(figsize=figsize)
    sns.countplot(data=df[[x,hue]],x=x,hue=hue)
    plt.title(title)
    plt.show()

# %%
countplot_of_2('outcome','family_history')

# %% [markdown]
# #### Multivariate analysis

# %%
plt.figure(figsize=(20,20))
plt.rc('xtick',labelsize=20) 
plt.rc('ytick', labelsize=20) 
sns.heatmap(df.corr(), annot=True )

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ## Seperate Predictors and target

# %%
X=df.iloc[:,:-1]
y=df.outcome

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X_test.shape
# Out:
# (92, 34)

# %%
X_train.shape
# Out:
# (274, 34)

# %%
y_train.shape
# Out:
# (274,)

# %%
y_test.shape
# Out:
# (92,)

# %%
# Scalar
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
X_train=scalar.fit_transform(X_train)
X_test=scalar.fit_transform(X_test)

# %%
model=LogisticRegression()    # For Logistic Regression
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
accuracy_score(y_predict,y_test)
# Out:
# 0.9782608695652174

# %%
confusion_matrix(y_predict,y_test)
# Out:
# array([[22,  0,  0,  0,  0,  0],
#        [ 0, 17,  0,  1,  0,  0],
#        [ 0,  0, 20,  0,  0,  0],
#        [ 0,  1,  0, 13,  0,  0],
#        [ 0,  0,  0,  0, 10,  0],
#        [ 0,  0,  0,  0,  0,  8]], dtype=int64)

# %%
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       0.94      0.94      0.94        18
#            3       1.00      1.00      1.00        20
#            4       0.93      0.93      0.93        14
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         8
#
#     accuracy                           0.98        92
#    macro avg       0.98      0.98      0.98        92
# weighted avg       0.98      0.98      0.98        92

# %%
model=KNeighborsClassifier()    # Metrics for KNN Model
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
accuracy_score(y_predict,y_test)
# Out:
# 0.9782608695652174

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()

# %%
X_train_smote,y_train_smote =smote.fit_resample(X_train.astype('float'),y_train)

# %%
X_train.shape
# Out:
# (274, 34)

# %%
from collections import Counter
print("Actual Classes",Counter(y_train))
print("SMOTE Classes",Counter(y_train_smote))
# Out:
# Actual Classes Counter({1: 90, 3: 52, 2: 43, 5: 42, 4: 35, 6: 12})
# SMOTE Classes Counter({4: 90, 3: 90, 1: 90, 5: 90, 2: 90, 6: 90})

# %%
model=KNeighborsClassifier()
model
model.fit(X_train_smote,y_train_smote)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from imblearn.under_sampling import NearMiss
near = NearMiss()

# %%
X_train_near,y_train_near = near.fit_resample(X_train.astype('float'),y_train) #.astype('float')

# %%
from collections import Counter
print("Actual Classes",Counter(y_train))
print("NEARMISS Classes",Counter(y_train_near))
# Out:
# Actual Classes Counter({1: 90, 3: 52, 2: 43, 5: 42, 4: 35, 6: 12})
# NEARMISS Classes Counter({1: 12, 2: 12, 3: 12, 4: 12, 5: 12, 6: 12})

# %%
model.fit(X_train_near,y_train_near)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.9456521739130435

# %%
confusion_matrix(y_predict,y_test)
# Out:
# array([[22,  0,  0,  0,  0,  0],
#        [ 0, 15,  0,  2,  0,  0],
#        [ 0,  0, 20,  0,  0,  0],
#        [ 0,  3,  0, 12,  0,  0],
#        [ 0,  0,  0,  0, 10,  0],
#        [ 0,  0,  0,  0,  0,  8]], dtype=int64)

# %%
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       0.83      0.88      0.86        17
#            3       1.00      1.00      1.00        20
#            4       0.86      0.80      0.83        15
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         8
#
#     accuracy                           0.95        92
#    macro avg       0.95      0.95      0.95        92
# weighted avg       0.95      0.95      0.95        92

# %%
model=DecisionTreeClassifier(max_depth=14)  # Descision Tree
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
accuracy_score(y_predict,y_test)
# Out:
# 0.9456521739130435

# %%
confusion_matrix(y_predict,y_test)
# Out:
# array([[21,  0,  0,  0,  0,  0],
#        [ 1, 16,  0,  0,  0,  0],
#        [ 0,  0, 19,  0,  0,  1],
#        [ 0,  1,  1, 14,  0,  0],
#        [ 0,  0,  0,  0, 10,  0],
#        [ 0,  1,  0,  0,  0,  7]], dtype=int64)

# %%
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.98        21
#            2       0.89      0.94      0.91        17
#            3       0.95      0.95      0.95        20
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        10
#            6       0.88      0.88      0.88         8
#
#     accuracy                           0.95        92
#    macro avg       0.94      0.94      0.94        92
# weighted avg       0.95      0.95      0.95        92

# %%
model=RandomForestClassifier(max_depth=15)
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
print(y_predict)
accuracy_score(y_predict,y_test)
# Out:
# [3 1 4 4 3 2 6 2 6 6 2 1 3 5 3 2 6 1 4 4 3 3 5 1 3 2 3 6 5 6 5 1 3 6 4 3 1
#  1 4 5 3 2 5 1 3 3 4 4 4 2 1 2 2 1 4 1 2 4 3 1 1 3 1 5 1 4 2 6 2 3 2 1 5 1
#  1 1 2 1 5 2 2 5 3 3 2 1 2 4 3 1 3 2]
# 0.967391304347826

# %% [markdown]
# ## Feature Importance

# %%
pd.DataFrame(model.feature_importances_, index=X.columns).sort_values(0, ascending=False)
# Out:
#                                                  0
# thinning_of_the_suprapapillary_epidermis  0.092907
# clubbing_of_the_rete_ridges               0.076307
# fibrosis_of_the_papillary_dermis          0.073611
# elongation_of_the_rete_ridges             0.066537
# koebner_phenomenon                        0.065403
# spongiosis                                0.065362
# focal_hypergranulosis                     0.045735
# melanin_incontinence                      0.040170
# vacuolisation_and_damage_of_basal_layer   0.038809
# PNL_infiltrate                            0.029702
# saw_tooth_appearance_of_retes             0.029096
# scalp_involvement                         0.028766
# knee_and_elbow_involvement                0.028318
# polygonal_papules                         0.028266
# exocytosis                                0.025809
# oral_mucosal_involvement                  0.023682
# band_like_infiltrate                      0.023258
# ...

# %% [markdown]
# ## The first 10 features will have impact on the skin disorder
